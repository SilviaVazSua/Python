# %% [markdown]
# ### NLTK BOOK, CHAPTER 1
# #### 1 Computing with Language: Texts and Words

# %% [markdown]
# from NLTK's book module, load all items.

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %% [markdown]
# concordances of "whale" in Moby Dick

# %%
text1.concordance('whale')
# Out:
# Displaying 25 of 25 matches:
# s , and to teach them by what name a whale - fish is to be called in our tongue
# t which is not true ." -- HACKLUYT " WHALE . ... Sw . and Dan . HVAL . This ani
# ulted ." -- WEBSTER ' S DICTIONARY " WHALE . ... It is more immediately from th
# ISH . WAL , DUTCH . HWAL , SWEDISH . WHALE , ICELANDIC . WHALE , ENGLISH . BALE
# HWAL , SWEDISH . WHALE , ICELANDIC . WHALE , ENGLISH . BALEINE , FRENCH . BALLE
# least , take the higgledy - piggledy whale statements , however authentic , in
#  dreadful gulf of this monster ' s ( whale ' s ) mouth , are immediately lost a
#  patient Job ." -- RABELAIS . " This whale ' s liver was two cartloads ." -- ST
#  Touching that monstrous bulk of the whale or ork we have received nothing cert
#  of oil will be extracted out of one whale ." -- IBID . " HISTORY OF LIFE AND D
# ise ." -- KING HENRY . " Very like a whale ." -- HAMLET . " Which to secure , n
# ...

# %% [markdown]
# What other words appear in a similar range of contexts?

# %%
text1.similar("whale")
# Out:
# ship boat sea time captain world man deck pequod other whales air
# water head crew line thing side way body

# %%
text1.common_contexts(["whale", "man"])
# Out:
# this_s the_or a_in the_in a_is the_s a_s a_of white_he white_a
# the_that the_he a_as a_some the_i a_from a_it the_of the_now the_to

# %% [markdown]
# Each stripe represents an instance of a word, and each row represents the entire text.

# %%
text3.dispersion_plot(["woman", "man"])

# %% [markdown]
# the length of a text from start to finish, in terms of the words and punctuation symbols that appear.
# How many token in Genesis?

# %%
len(text3)
# Out:
# 44764

# %% [markdown]
# all different tokens in Genesis, sorted.

# %%
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %% [markdown]
# how many types in Genesis?

# %%
len(set(text3))
# Out:
# 2789

# %% [markdown]
# lexical richness of the text: the number of distinct words is just 6% of the total number of words, or equivalently that each word is used 16 times on average

# %%
len(set(text3)) / len(text3)
# Out:
# 0.06230453042623537

# %%
how many times appear the word "lol" in text5?

# %%
text5.count("lol")
# Out:
# 704

# %% [markdown]
# How much is this as a percentage of the total number of words in this text?

# %%
100 * text5.count('a') / len(text5)
# Out:
# 1.261941790713175

# %%
We can define a function to avoid repetition.

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(text5)
# Out:
# 0.13477005109975562

# %%
def percentage(count, total):
    return 100 * count / total

# %%
percentage(text5.count('a'), len(text5))
# Out:
# 1.261941790713175
